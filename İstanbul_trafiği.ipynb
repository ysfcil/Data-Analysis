# %%
import urllib
import pandas as pd
df = pd.read_csv(r"C:\Users\yusuf\Downloads\Ocak 2020 Trafik Yo_unluk Verisi.csv")

# %%
df.head()
# Out:
#    _id            DATE_TIME   LATITUDE  LONGITUDE GEOHASH  MINIMUM_SPEED  \
# 0    1  2020-01-01T00:00:00  28.811646  41.080627  sxk3xw            135
# 1    2  2020-01-01T00:00:00  29.108276  40.987244  sxk9nm            143
# 2    3  2020-01-01T00:00:00  29.097290  41.003723  sxk9q0            128
# 3    4  2020-01-01T00:00:00  28.679810  40.998230  sxk3hx            111
# 4    5  2020-01-01T00:00:00  28.020630  41.042175  sx7cmx             99
#
#    MAXIMUM_SPEED  AVERAGE_SPEED  NUMBER_OF_VEHICLES
# 0             18             81                 132
# 1             10             73                 162
# 2              6             50                 110
# 3             22             68                 101
# 4             99             99                   1

# %%
import matplotlib.pyplot as plt
df.plot(kind="scatter", x="LATITUDE", y="LONGITUDE", grid=True, alpha = 0.01)
plt.show()

# %%
df.plot(kind="scatter", x="LATITUDE", y="LONGITUDE", grid=True, alpha = 0.3,
c=df["NUMBER_OF_VEHICLES"] / 100, label="NUMBER_OF_VEHICLES", cmap="jet",s=0.3, colorbar=True,
legend=True, sharex=False, figsize=(16, 9))
plt.show()

# %%
# Out:
# 1676399
